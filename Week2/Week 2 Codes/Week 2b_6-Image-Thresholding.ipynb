# %% [markdown]
# # Image Thresholding

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#img = cv2.imre  ad('rainbow.jpg')
img = cv2.imread('UnoCardGreen5.jpg')

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()

# %%
# Adding the 0 flag to read it in black and white
#img = cv2.imread('rainbow.jpg')
img = cv2.imread('UnoCardGreen5.jpg',0)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()
print(img.shape)
# Out:
# (720, 1280, 3)

# %%
plt.imshow(img,cmap='gray')
plt.show()

# %% [markdown]
# ## Different Threshold Types

# %% [markdown]
# ### Binary

# %%
ret,thresh1 = cv2.threshold(img,100,255,cv2.THRESH_BINARY)

# %%
plt.imshow(img,cmap='gray')
plt.show()

# %%
ret
# Out:
# 100.0

# %%
plt.imshow(thresh1,cmap='gray')
plt.show()

# %% [markdown]
# ### Binary Inverse

# %%
ret,thresh2 = cv2.threshold(img,100,255,cv2.THRESH_BINARY_INV)
plt.imshow(thresh2,cmap='gray')
plt.show()

# %% [markdown]
# ###  Threshold Truncation

# %%
ret,thresh3 = cv2.threshold(img,100,255,cv2.THRESH_TRUNC)
plt.imshow(thresh3,cmap='gray')
plt.show()

# %% [markdown]
# ### Threshold to Zero

# %%
ret,thresh4 = cv2.threshold(img,100,255,cv2.THRESH_TOZERO)
plt.imshow(thresh4,cmap='gray')
plt.show()

# %% [markdown]
# ### Threshold to Zero (Inverse)

# %%
ret,thresh5 = cv2.threshold(img,100,255,cv2.THRESH_TOZERO_INV)
plt.imshow(thresh5,cmap='gray')
plt.show()

# %% [markdown]
# # Real World Applications
#
# ## Adaptive Thresholding
#
#
#
# ### Sudoku Image

# %%
#img = cv2.imread("crossword.jpg",0)
img = cv2.imread("UnoCardGreen5.jpg",0)

# %%
def show_pic(img):
    fig = plt.figure(figsize=(7,7))
    ax = fig.add_subplot(121)
    ax.imshow(img,cmap='gray')
    ax2 = fig.add_subplot(122)
    ret,th1 = cv2.threshold(img,100,255,cv2.THRESH_BINARY)
    ax2.imshow(th1, cmap="gray")
    plt.show()

# %%
show_pic(img)

# %% [markdown]
# ## Simple Binary

# %%
ret,th1 = cv2.threshold(img,100,255,cv2.THRESH_BINARY)

# %%
show_pic(th1)

# %% [markdown]
# ### Adaptive Threshold
#
# https://stackoverflow.com/questions/28763419/adaptive-threshold-parameters-confusion
#
#     @param src Source 8-bit single-channel image.
#     .   @param dst Destination image of the same size and the same type as src.
#     .   @param maxValue Non-zero value assigned to the pixels for which the condition is satisfied
#     .   @param adaptiveMethod Adaptive thresholding algorithm to use, see #AdaptiveThresholdTypes.
#     .   The #BORDER_REPLICATE | #BORDER_ISOLATED is used to process boundaries.
#     .   @param thresholdType Thresholding type that must be either #THRESH_BINARY or #THRESH_BINARY_INV,
#     .   see #ThresholdTypes.
#     .   @param blockSize Size of a pixel neighborhood that is used to calculate a threshold value for the
#     .   pixel: 3, 5, 7, and so on.
#     .   @param C Constant subtracted from the mean or weighted mean (see the details below). Normally, it
#     .   is positive but may be zero or negative as well.

# %%
def show_pic(img):
    fig = plt.figure(figsize=(7,7))
    ax = fig.add_subplot(121)
    ax.imshow(img,cmap='gray')
    ax2 = fig.add_subplot(122)
    th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,13,8) # Play around with these last 2 numbers
    #ret,th1 = cv2.threshold(img,100,255,cv2.THRESH_BINARY)
    ax2.imshow(th2, cmap="gray")
    plt.show()

# %%
#th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,15,9) # Play around with these last 2 numbers
show_pic(img)

# %%
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,13,8)

# %%
show_pic(th3)

# %%
blended = cv2.addWeighted(src1=th1,alpha=0.7,src2=th2,beta=0.3,gamma=0)
show_pic(blended)

# %% [markdown]
# ## The end
