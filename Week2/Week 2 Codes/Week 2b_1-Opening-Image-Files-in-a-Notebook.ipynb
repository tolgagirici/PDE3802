# %% [markdown]
# # Opening Image Files in a Notebook

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### WARNING! Make sure to provide the correct path like we do in our notebooks! ALWAYS confirm that your file path is correct before posting a question on this.

# %%
# WONT GIVE ERROR! GIVES NONE INSTEAD!!!
img = cv2.imread("some/wrong/path.jpg")

# %%
# UH OH!!
print(img)
# Out:
# None

# %%
img = cv2.imread('puppy.jpg')

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %% [markdown]
# ------------

# %%
img_bgr = cv2.imread('puppy.jpg')
plt.imshow(img_bgr)
plt.show()

# %% [markdown]
# The image has been correctly loaded by openCV as a numpy array, but the color of each pixel has been sorted as BGR.
# Matplotlib's plot expects an RGB image so, for a correct display of the image, it is necessary to swap those channels.
# This operation can be done either by using openCV conversion functions cv2.cvtColor() or by working directly with the numpy array.

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
img_gray = cv2.imread('puppy.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray)
plt.show()
img_gray.shape
# Out:
# (1300, 1950)

# %%
img_gray = cv2.imread('puppy.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray,cmap='gray')
plt.show()

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %% [markdown]
# ## Resize Images

# %%
img_rgb.shape
# width, height, color channels
# Out:
# (1300, 1950, 3)

# %%
img =cv2.resize(img_rgb,(1300,275)) #opencv is opposite to numpy in terms of x and y dimensions of an array.

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# ### By ratio

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img =cv2.resize(img_rgb,(0,0),img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)
plt.show()
print(new_img.shape)
# Out:
# (650, 975, 3)

# %%
import PyQt5

# %%
# %matplotlib qt
plt.imshow(new_img)

# %% [markdown]
# ### Flipping Images

# %%
# %matplotlib inline

# %%
# Along central x axis
new_img = cv2.flip(new_img,0)
plt.imshow(new_img)
plt.show()

# %%
# Along central y axis
new_img = cv2.flip(new_img,1)
plt.imshow(new_img)
plt.show()

# %%
# Along both axis
new_img = cv2.flip(new_img,-1)
plt.imshow(new_img)
plt.show()

# %% [markdown]
# --------

# %% [markdown]
# # Saving Image Files

# %%
type(new_img)
new_img = cv2.cvtColor(new_img, cv2.COLOR_RGB2BGR)

# %%
cv2.imwrite('my_new_picture.jpg',new_img)
# Out:
# True

# %% [markdown]
# Keep in mind, the above stored the BGR version of the image.

# %% [markdown]
# ## Larger Displays in the Notebook

# %%
new_img = cv2.cvtColor(new_img, cv2.COLOR_BGR2RGB)

fig = plt.figure(figsize=(5,5)) #in inches
ax = fig.add_subplot(221) #one by one subplot
ax.imshow(new_img)
ax2 = fig.add_subplot(222) #one by one subplot
ax2.imshow(new_img)
ax3 = fig.add_subplot(223) #one by one subplot
ax3.imshow(new_img)
ax4 = fig.add_subplot(224) #one by one subplot
ax4.imshow(new_img)
plt.show()
